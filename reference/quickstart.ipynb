# %% [markdown]
# <a href="https://colab.research.google.com/github/intelligent-environments-lab/CityLearn/blob/master/examples/quickstart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # QuickStart
#
# Install the latest CityLearn version from PyPi with the :code:`pip` command:

# %% [markdown]
# ## CityLearn Control Agents

# %% [markdown]
# ### No Control (Baseline)
#
# Run the following to simulate an environment where the storage systems and heat pumps are not controlled (baseline). The storage actions prescribed will be 0.0 and the heat pump will have no action, i.e. `None`, causing it to deliver the ideal load in the building time series files:

# %%
from citylearn.agents.base import Agent as Agent
from citylearn.citylearn import CityLearnEnv

# initialize
env = CityLearnEnv('citylearn_challenge_2023_phase_2_local_evaluation', central_agent=True)
# print(env.schema)
model = Agent(env)

# step through environment and apply agent actions
observations, _ = env.reset()

while not env.terminated:
    actions = model.predict(observations)
    observations, reward, info, terminated, truncated = env.step(actions)

# test
kpis = model.env.evaluate()
kpis = kpis.pivot(index='cost_function', columns='name', values='value').round(3)
kpis = kpis.dropna(how='all')
display(kpis)
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.
# /home/casey/Documents/Graduate_School/24_Fall/CS138/Fa24-CS-138-_FinalProject/.venv/lib/python3.10/site-packages/citylearn/dynamics.py:118: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.load_state_dict(torch.load(self.filepath)['model_state_dict'])
# {'random_seed': 2023, 'root_directory': '/home/casey/.cache/citylearn/v2.2.0/datasets/citylearn_challenge_2023_phase_2_local_evaluation', 'central_agent': True, 'simulation_start_time_step': 0, 'simulation_end_time_step': 719, 'episode_time_steps': None, 'rolling_episode_split': False, 'random_episode_split': False, 'seconds_per_time_step': 3600.0, 'observations': {'month': {'active': False, 'shared_in_central_agent': True}, 'day_type': {'active': True, 'shared_in_central_agent': True}, 'hour': {'active': True, 'shared_in_central_agent': True}, 'daylight_savings_status': {'active': False, 'shared_in_central_agent': True}, 'outdoor_dry_bulb_temperature': {'active': True, 'shared_in_central_agent': True}, 'outdoor_dry_bulb_temperature_predicted_1': {'active': True, 'shared_in_central_agent': True}, 'outdoor_dry_bulb_temperature_predicted_2': {'active': True, 'shared_in_central_agent': True}, 'outdoor_dry_bulb_temperature_predicted_3': {'active': True, 'shared_in_central_agent': True}, 'outdoor_relative_humidity': {'active': False, 'shared_in_central_agent': True}, 'outdoor_relative_humidity_predicted_1': {'active': False, 'shared_in_central_agent': True}, 'outdoor_relative_humidity_predicted_2': {'active': False, 'shared_in_central_agent': True}, 'outdoor_relative_humidity_predicted_3': {'active': False, 'shared_in_central_agent': True}, 'diffuse_solar_irradiance': {'active': True, 'shared_in_central_agent': True}, 'diffuse_solar_irradiance_predicted_1': {'active': True, 'shared_in_central_agent': True}, 'diffuse_solar_irradiance_predicted_2': {'active': True, 'shared_in_central_agent': True}, 'diffuse_solar_irradiance_predicted_3': {'active': True, 'shared_in_central_agent': True}, 'direct_solar_irradiance': {'active': True, 'shared_in_central_agent': True}, 'direct_solar_irradiance_predicted_1': {'active': True, 'shared_in_central_agent': True}, 'direct_solar_irradiance_predicted_2': {'active': True, 'shared_in_central_agent': True}, 'direct_solar_irradiance_predicted_3': {'active': True, 'shared_in_central_agent': True}, 'carbon_intensity': {'active': True, 'shared_in_central_agent': True}, 'indoor_dry_bulb_temperature': {'active': True, 'shared_in_central_agent': False}, 'average_unmet_cooling_setpoint_difference': {'active': False, 'shared_in_central_agent': False}, 'indoor_relative_humidity': {'active': False, 'shared_in_central_agent': False}, 'non_shiftable_load': {'active': True, 'shared_in_central_agent': False}, 'solar_generation': {'active': True, 'shared_in_central_agent': False}, 'cooling_storage_soc': {'active': False, 'shared_in_central_agent': False}, 'heating_storage_soc': {'active': False, 'shared_in_central_agent': False}, 'dhw_storage_soc': {'active': True, 'shared_in_central_agent': False}, 'electrical_storage_soc': {'active': True, 'shared_in_central_agent': False}, 'net_electricity_consumption': {'active': True, 'shared_in_central_agent': False}, 'electricity_pricing': {'active': True, 'shared_in_central_agent': True}, 'electricity_pricing_predicted_1': {'active': True, 'shared_in_central_agent': True}, 'electricity_pricing_predicted_2': {'active': True, 'shared_in_central_agent': True}, 'electricity_pricing_predicted_3': {'active': True, 'shared_in_central_agent': True}, 'cooling_device_efficiency': {'active': False, 'shared_in_central_agent': False}, 'heating_device_efficiency': {'active': False, 'shared_in_central_agent': False}, 'cooling_demand': {'active': True, 'shared_in_central_agent': False}, 'heating_demand': {'active': False, 'shared_in_central_agent': False}, 'dhw_demand': {'active': True, 'shared_in_central_agent': False}, 'cooling_electricity_consumption': {'active': False, 'shared_in_central_agent': False}, 'heating_electricity_consumption': {'active': False, 'shared_in_central_agent': False}, 'dhw_electricity_consumption': {'active': False, 'shared_in_central_agent': False}, 'occupant_count': {'active': True, 'shared_in_central_agent': False}, 'power_outage': {'active': True, 'shared_in_ce ...
# name                                           Building_1  Building_2  \
# cost_function
# all_time_peak_average                                 NaN         NaN
# annual_normalized_unserved_energy_total             0.010       0.013
# carbon_emissions_total                              1.712       1.771
# cost_total                                          1.660       1.713
# daily_one_minus_load_factor_average                   NaN         NaN
# daily_peak_average                                    NaN         NaN
# discomfort_cold_delta_average                       8.678       3.579
# discomfort_cold_delta_maximum                      16.078      11.616
# discomfort_cold_delta_minimum                       0.000       0.000
# discomfort_cold_proportion                          0.965       0.776
# discomfort_hot_delta_average                        0.006       0.095
# discomfort_hot_delta_maximum                        1.346       5.100
# discomfort_hot_delta_minimum                        0.000       0.000
# discomfort_hot_proportion                           0.000       0.024
# discomfort_proportion                               0.965       0.800
# electricity_consumption_total                       1.728       1.800
# monthly_one_minus_load_factor_average                 NaN         NaN
# one_minus_thermal_resilience_proportion             0.667       0.643
# power_outage_normalized_unserved_energy_total       0.705       0.689
# ramping_average                                       NaN         NaN
# zero_net_energy                                     1.725       1.714
#
# name                                           Building_3  District
# cost_function
# all_time_peak_average                                 NaN     1.021
# annual_normalized_unserved_energy_total             0.012     0.012
# carbon_emissions_total                              1.506     1.663
# cost_total                                          1.494     1.622
# daily_one_minus_load_factor_average                   NaN     0.853
# daily_peak_average                                    NaN     1.344
# discomfort_cold_delta_average                       2.776     5.011
# discomfort_cold_delta_maximum                       6.387    11.360
# discomfort_cold_delta_minimum                       0.000     0.000
# discomfort_cold_proportion                          0.810     0.850
# discomfort_hot_delta_average                        0.021     0.040
# discomfort_hot_delta_maximum                        3.171     3.206
# discomfort_hot_delta_minimum                        0.000     0.000
# discomfort_hot_proportion                           0.003     0.009
# discomfort_proportion                               0.814     0.860
# electricity_consumption_total                       1.526     1.685
# monthly_one_minus_load_factor_average                 NaN     0.867
# one_minus_thermal_resilience_proportion             0.333     0.548
# power_outage_normalized_unserved_energy_total       0.663     0.686
# ramping_average                                       NaN     2.251
# zero_net_energy                                     1.522     1.654

# %% [markdown]
# ### Centralized RBC
# Run the following to simulate an environment controlled by centralized RBC agent for a single episode:

# %%
from citylearn.agents.rbc import BasicRBC as Agent
from citylearn.citylearn import CityLearnEnv

# initialize
env = CityLearnEnv('citylearn_challenge_2023_phase_2_local_evaluation', central_agent=True)
model = Agent(env)

# step through environment and apply agent actions
observations, _ = env.reset()

while not env.terminated:
    actions = model.predict(observations)
    observations, reward, info, terminated, truncated = env.step(actions)

# test
kpis = model.env.evaluate()
kpis = kpis.pivot(index='cost_function', columns='name', values='value').round(3)
kpis = kpis.dropna(how='all')
display(kpis)
# Out:
# /home/casey/Documents/Graduate_School/24_Fall/CS138/Fa24-CS-138-_FinalProject/.venv/lib/python3.10/site-packages/citylearn/dynamics.py:118: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.load_state_dict(torch.load(self.filepath)['model_state_dict'])
# name                                           Building_1  Building_2  \
# cost_function
# all_time_peak_average                                 NaN         NaN
# annual_normalized_unserved_energy_total             0.017       0.016
# carbon_emissions_total                              1.998       1.936
# cost_total                                          1.931       1.878
# daily_one_minus_load_factor_average                   NaN         NaN
# daily_peak_average                                    NaN         NaN
# discomfort_cold_delta_average                       9.825       3.493
# discomfort_cold_delta_maximum                      13.774       9.875
# discomfort_cold_delta_minimum                       0.000       0.000
# discomfort_cold_proportion                          0.975       0.899
# discomfort_hot_delta_average                        0.005       0.022
# discomfort_hot_delta_maximum                        1.456       4.526
# discomfort_hot_delta_minimum                        0.000       0.000
# discomfort_hot_proportion                           0.000       0.007
# discomfort_proportion                               0.975       0.907
# electricity_consumption_total                       1.995       1.963
# monthly_one_minus_load_factor_average                 NaN         NaN
# one_minus_thermal_resilience_proportion             0.667       0.500
# power_outage_normalized_unserved_energy_total       0.781       0.759
# ramping_average                                       NaN         NaN
# zero_net_energy                                     2.059       1.994
#
# name                                           Building_3  District
# cost_function
# all_time_peak_average                                 NaN     1.179
# annual_normalized_unserved_energy_total             0.016     0.016
# carbon_emissions_total                              1.740     1.891
# cost_total                                          1.713     1.841
# daily_one_minus_load_factor_average                   NaN     0.720
# daily_peak_average                                    NaN     1.352
# discomfort_cold_delta_average                       3.189     5.502
# discomfort_cold_delta_maximum                       5.514     9.721
# discomfort_cold_delta_minimum                       0.000     0.000
# discomfort_cold_proportion                          0.953     0.942
# discomfort_hot_delta_average                        0.010     0.012
# discomfort_hot_delta_maximum                        3.230     3.071
# discomfort_hot_delta_minimum                        0.000     0.000
# discomfort_hot_proportion                           0.003     0.004
# discomfort_proportion                               0.957     0.946
# electricity_consumption_total                       1.755     1.904
# monthly_one_minus_load_factor_average                 NaN     0.863
# one_minus_thermal_resilience_proportion             0.267     0.478
# power_outage_normalized_unserved_energy_total       0.711     0.750
# ramping_average                                       NaN     0.959
# zero_net_energy                                     1.773     1.942

# %% [markdown]
# ### Decentralized-Independent SAC
#
# Run the following to simulate an environment controlled by decentralized-independent SAC agents for 1 training episode:

# %%
from citylearn.agents.sac import SAC as Agent
from citylearn.citylearn import CityLearnEnv

# initialize
env = CityLearnEnv('citylearn_challenge_2023_phase_2_local_evaluation', central_agent=False)
model = Agent(env)

# train
model.learn(episodes=2, deterministic_finish=True)

# test
kpis = model.env.evaluate()
kpis = kpis.pivot(index='cost_function', columns='name', values='value').round(3)
kpis = kpis.dropna(how='all')
display(kpis)
# Out:
# /home/casey/Documents/Graduate_School/24_Fall/CS138/Fa24-CS-138-_FinalProject/.venv/lib/python3.10/site-packages/citylearn/dynamics.py:118: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.load_state_dict(torch.load(self.filepath)['model_state_dict'])
# /home/casey/Documents/Graduate_School/24_Fall/CS138/Fa24-CS-138-_FinalProject/.venv/lib/python3.10/site-packages/citylearn/dynamics.py:118: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.load_state_dict(torch.load(self.filepath)['model_state_dict'])
# name                                           Building_1  Building_2  \
# cost_function
# all_time_peak_average                                 NaN         NaN
# annual_normalized_unserved_energy_total             0.013       0.013
# carbon_emissions_total                              0.950       0.972
# cost_total                                          0.913       0.933
# daily_one_minus_load_factor_average                   NaN         NaN
# daily_peak_average                                    NaN         NaN
# discomfort_cold_delta_average                       1.960       0.918
# discomfort_cold_delta_maximum                       6.459       4.527
# discomfort_cold_delta_minimum                       0.000       0.000
# discomfort_cold_proportion                          0.460       0.317
# discomfort_hot_delta_average                        0.229       0.543
# discomfort_hot_delta_maximum                        4.531       6.167
# discomfort_hot_delta_minimum                        0.000       0.000
# discomfort_hot_proportion                           0.036       0.151
# discomfort_proportion                               0.496       0.468
# electricity_consumption_total                       0.960       0.989
# monthly_one_minus_load_factor_average                 NaN         NaN
# one_minus_thermal_resilience_proportion             0.733       0.500
# power_outage_normalized_unserved_energy_total       0.630       0.648
# ramping_average                                       NaN         NaN
# zero_net_energy                                     0.976       0.992
#
# name                                           Building_3  District
# cost_function
# all_time_peak_average                                 NaN     0.949
# annual_normalized_unserved_energy_total             0.012     0.013
# carbon_emissions_total                              0.948     0.956
# cost_total                                          0.916     0.920
# daily_one_minus_load_factor_average                   NaN     0.941
# daily_peak_average                                    NaN     0.931
# discomfort_cold_delta_average                       0.912     1.263
# discomfort_cold_delta_maximum                       3.071     4.686
# discomfort_cold_delta_minimum                       0.000     0.000
# discomfort_cold_proportion                          0.263     0.347
# discomfort_hot_delta_average                        0.281     0.351
# discomfort_hot_delta_maximum                        3.918     4.872
# discomfort_hot_delta_minimum                        0.000     0.000
# discomfort_hot_proportion                           0.028     0.072
# discomfort_proportion                               0.291     0.419
# electricity_consumption_total                       0.962     0.971
# monthly_one_minus_load_factor_average                 NaN     0.994
# one_minus_thermal_resilience_proportion             0.133     0.456
# power_outage_normalized_unserved_energy_total       0.596     0.625
# ramping_average                                       NaN     0.882
# zero_net_energy                                     0.963     0.977

# %% [markdown]
# ### Decentralized-Cooperative MARLISA
#
# Run the following to simulate an environment controlled by decentralized-cooperative MARLISA agents for 1 training episodes:

# %%
from citylearn.agents.marlisa import MARLISA as Agent
from citylearn.citylearn import CityLearnEnv

# initialize
env = CityLearnEnv('citylearn_challenge_2023_phase_2_local_evaluation', central_agent=False)
model = Agent(env)

# train
model.learn(episodes=2, deterministic_finish=True)

# test
kpis = model.env.evaluate()
kpis = kpis.pivot(index='cost_function', columns='name', values='value').round(3)
kpis = kpis.dropna(how='all')
display(kpis)
# Out:
# /home/casey/Documents/Graduate_School/24_Fall/CS138/Fa24-CS-138-_FinalProject/.venv/lib/python3.10/site-packages/citylearn/dynamics.py:118: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.load_state_dict(torch.load(self.filepath)['model_state_dict'])
# /home/casey/Documents/Graduate_School/24_Fall/CS138/Fa24-CS-138-_FinalProject/.venv/lib/python3.10/site-packages/citylearn/dynamics.py:118: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.load_state_dict(torch.load(self.filepath)['model_state_dict'])
# name                                           Building_1  Building_2  \
# cost_function
# all_time_peak_average                                 NaN         NaN
# annual_normalized_unserved_energy_total             0.013       0.013
# carbon_emissions_total                              0.954       0.977
# cost_total                                          0.916       0.938
# daily_one_minus_load_factor_average                   NaN         NaN
# daily_peak_average                                    NaN         NaN
# discomfort_cold_delta_average                       1.960       0.917
# discomfort_cold_delta_maximum                       6.461       4.528
# discomfort_cold_delta_minimum                       0.000       0.000
# discomfort_cold_proportion                          0.461       0.319
# discomfort_hot_delta_average                        0.231       0.544
# discomfort_hot_delta_maximum                        4.563       6.144
# discomfort_hot_delta_minimum                        0.000       0.000
# discomfort_hot_proportion                           0.039       0.149
# discomfort_proportion                               0.501       0.468
# electricity_consumption_total                       0.964       0.995
# monthly_one_minus_load_factor_average                 NaN         NaN
# one_minus_thermal_resilience_proportion             0.733       0.500
# power_outage_normalized_unserved_energy_total       0.632       0.649
# ramping_average                                       NaN         NaN
# zero_net_energy                                     0.980       0.997
#
# name                                           Building_3  District
# cost_function
# all_time_peak_average                                 NaN     0.949
# annual_normalized_unserved_energy_total             0.012     0.013
# carbon_emissions_total                              0.963     0.965
# cost_total                                          0.931     0.928
# daily_one_minus_load_factor_average                   NaN     0.938
# daily_peak_average                                    NaN     0.934
# discomfort_cold_delta_average                       0.896     1.258
# discomfort_cold_delta_maximum                       3.045     4.678
# discomfort_cold_delta_minimum                       0.000     0.000
# discomfort_cold_proportion                          0.253     0.344
# discomfort_hot_delta_average                        0.288     0.354
# discomfort_hot_delta_maximum                        3.927     4.878
# discomfort_hot_delta_minimum                        0.000     0.000
# discomfort_hot_proportion                           0.028     0.072
# discomfort_proportion                               0.281     0.417
# electricity_consumption_total                       0.977     0.979
# monthly_one_minus_load_factor_average                 NaN     0.992
# one_minus_thermal_resilience_proportion             0.133     0.456
# power_outage_normalized_unserved_energy_total       0.598     0.626
# ramping_average                                       NaN     0.883
# zero_net_energy                                     0.978     0.985

# %% [markdown]
# ## Other Standard Reinforcement Learning Libraries

# %% [markdown]
# ### Stable Baselines3 Reinforcement Learning Algorithms
#
# Install the latest version of Stable Baselines3:

# %% [markdown]
# Before the environment is ready for use in Stable Baselines3, it needs to be wrapped. Firstly, wrap the environment using the `NormalizedObservationWrapper` (see [docs](https://www.citylearn.net/api/citylearn.wrappers.html#citylearn.wrappers.NormalizedObservationWrapper)) to ensure that observations served to the agent are min-max normalized between [0, 1] and cyclical observations e.g. hour, are encoded using the cosine transformation.
#
# Next, we wrap with the `StableBaselines3Wrapper` (see [docs](https://www.citylearn.net/api/citylearn.wrappers.html#citylearn.wrappers.StableBaselines3Wrapper)) that ensures observations, actions and rewards are served in manner that is compatible with Stable Baselines3 interface.
#
# > ⚠️ **NOTE**: `central_agent` in the `env` must be `True` when using Stable Baselines3  as it does not support multi-agents.

# %%
from stable_baselines3.sac import SAC as Agent
from citylearn.citylearn import CityLearnEnv
from citylearn.wrappers import NormalizedObservationWrapper, StableBaselines3Wrapper

# initialize
env = CityLearnEnv('citylearn_challenge_2023_phase_2_local_evaluation', central_agent=True)
env = NormalizedObservationWrapper(env)
env = StableBaselines3Wrapper(env)
model = Agent('MlpPolicy', env)

# train
episodes = 2
model.learn(total_timesteps=env.unwrapped.time_steps*episodes)

# test
observations, _ = env.reset()

while not env.unwrapped.terminated:
    actions, _ = model.predict(observations, deterministic=True)
    observations, _, _, _, _ = env.step(actions)

kpis = env.unwrapped.evaluate()
kpis = kpis.pivot(index='cost_function', columns='name', values='value').round(3)
kpis = kpis.dropna(how='all')
display(kpis)
# Out:
# /home/casey/Documents/Graduate_School/24_Fall/CS138/Fa24-CS-138-_FinalProject/.venv/lib/python3.10/site-packages/citylearn/dynamics.py:118: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.load_state_dict(torch.load(self.filepath)['model_state_dict'])
# name                                           Building_1  Building_2  \
# cost_function
# all_time_peak_average                                 NaN         NaN
# annual_normalized_unserved_energy_total             0.015       0.008
# carbon_emissions_total                              0.383       0.456
# cost_total                                          0.363       0.438
# daily_one_minus_load_factor_average                   NaN         NaN
# daily_peak_average                                    NaN         NaN
# discomfort_cold_delta_average                       0.000       0.004
# discomfort_cold_delta_maximum                       0.124       0.581
# discomfort_cold_delta_minimum                       0.000       0.000
# discomfort_cold_proportion                          0.000       0.000
# discomfort_hot_delta_average                        9.435       6.928
# discomfort_hot_delta_maximum                       16.671      14.596
# discomfort_hot_delta_minimum                        0.000       0.000
# discomfort_hot_proportion                           0.982       0.978
# discomfort_proportion                               0.982       0.978
# electricity_consumption_total                       0.387       0.482
# monthly_one_minus_load_factor_average                 NaN         NaN
# one_minus_thermal_resilience_proportion             1.000       1.000
# power_outage_normalized_unserved_energy_total       0.566       0.366
# ramping_average                                       NaN         NaN
# zero_net_energy                                     0.268       0.381
#
# name                                           Building_3  District
# cost_function
# all_time_peak_average                                 NaN     0.837
# annual_normalized_unserved_energy_total             0.013     0.012
# carbon_emissions_total                              0.524     0.454
# cost_total                                          0.493     0.431
# daily_one_minus_load_factor_average                   NaN     1.281
# daily_peak_average                                    NaN     0.683
# discomfort_cold_delta_average                       0.001     0.002
# discomfort_cold_delta_maximum                       0.394     0.366
# discomfort_cold_delta_minimum                       0.000     0.000
# discomfort_cold_proportion                          0.000     0.000
# discomfort_hot_delta_average                        6.592     7.652
# discomfort_hot_delta_maximum                       11.968    14.412
# discomfort_hot_delta_minimum                        0.000     0.000
# discomfort_hot_proportion                           0.978     0.979
# discomfort_proportion                               0.978     0.979
# electricity_consumption_total                       0.530     0.467
# monthly_one_minus_load_factor_average                 NaN     1.123
# one_minus_thermal_resilience_proportion             1.000     1.000
# power_outage_normalized_unserved_energy_total       0.531     0.488
# ramping_average                                       NaN     0.968
# zero_net_energy                                     0.483     0.377

# %% [markdown]
# ### RLlib
#
# Install the latest version of RLlib:

# %% [markdown]
# We advise that you include the `ClippedObservationWrapper` (see [docs](https://www.citylearn.net/api/citylearn.wrappers.html#citylearn.wrappers.ClippedObservationWrapper)) wrapper when working with RLlib so that observations are always clipped within the observation space before sending to the agent if not, out-of-bound observations will raise a `ValueError` and terminate the training.
#
# We also wrap the environment with `NormalizedObservationWrapper` (see [docs](https://www.citylearn.net/api/citylearn.wrappers.html#citylearn.wrappers.NormalizedObservationWrapper)) to ensure that observations served to the agent are min-max normalized between [0, 1] and cyclical observations e.g. hour, are encoded using the cosine transformation.
#
# RLlib supports both [single-agent and multi-agent algorithms](https://docs.ray.io/en/latest/rllib/rllib-algorithms.html). See below for an example for either case.

# %% [markdown]
# ####  Single Agent
#
# The single-agent interface for RLlib is the `RLlibSingleAgentWrapper` wrapper.

# %%
import warnings
from citylearn.wrappers import ClippedObservationWrapper, NormalizedObservationWrapper, RLlibSingleAgentWrapper
from ray.rllib.algorithms.sac import SACConfig as Config

warnings.filterwarnings('ignore', category=DeprecationWarning)

# initialize
env_config = {
    'env_kwargs': {
        'schema': 'citylearn_challenge_2023_phase_2_local_evaluation',
    },
    'wrappers': [
        NormalizedObservationWrapper, 
        ClippedObservationWrapper
    ]
}
config = (
    Config()
    .environment(RLlibSingleAgentWrapper, env_config=env_config)
)
model = config.build()

# train
for i in range(2):
    _ = model.train()

# test
env = RLlibSingleAgentWrapper(env_config)
observations, _ = env.reset()

while not env.unwrapped.terminated:
    actions = model.compute_single_action(observations, explore=False)
    observations, _, _, _, _ = env.step(actions)

kpis = env.unwrapped.evaluate()
kpis = kpis.pivot(index='cost_function', columns='name', values='value').round(3)
kpis = kpis.dropna(how='all')
display(kpis)
# Out:
# 2024-11-25 16:28:12,554	WARNING deprecation.py:50 -- DeprecationWarning: `rllib/algorithms/simple_q/` has been deprecated. Use `rllib_contrib/simple_q/` instead. This will raise an error in the future!
# /home/casey/Documents/Graduate_School/24_Fall/CS138/Fa24-CS-138-_FinalProject/.venv/lib/python3.10/site-packages/citylearn/dynamics.py:118: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.load_state_dict(torch.load(self.filepath)['model_state_dict'])
# 2024-11-25 16:28:13,820	WARNING env.py:162 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# 2024-11-25 16:28:14,053	WARNING util.py:62 -- Install gputil for GPU system monitoring.
# /home/casey/Documents/Graduate_School/24_Fall/CS138/Fa24-CS-138-_FinalProject/.venv/lib/python3.10/site-packages/citylearn/dynamics.py:118: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.load_state_dict(torch.load(self.filepath)['model_state_dict'])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 33
#      31 while not env.unwrapped.terminated:
#      32     actions = model.compute_single_action(observations, explore=False)
# ---> 33     observations, _, _, _, _ = env.step(actions)
#      35 kpis = env.unwrapped.evaluate()
#      36 kpis = kpis.pivot(index='cost_function', columns='name', values='value').round(3)
#
# File ~/Documents/Graduate_School/24_Fall/CS138/Fa24-CS-138-_FinalProject/.venv/lib/python3.10/site-packages/gymnasium/core.py:408, in Wrapper.step(self, action)
#     404 def step(
#     405     self, action: WrapperActType
#     406 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     407     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 408     return self.env.step(action)
#
# File ~/Documents/Graduate_School/24_Fall/CS138/Fa24-CS-138-_FinalProject/.venv/lib/python3.10/site-packages/gymnasium/core.py:469, in ObservationWrapper.step(self, action)
#     465 def step(
#     466     self, action: ActType
#     467 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     468     """Modifies the :attr:`env` after calling :meth:`step` using :meth:`self.observation` on the returned observations."""
# --> 469     observation, reward, terminated, truncated, info = self.env.step(action)
#     470     return self.observation(observation), reward, terminated, truncated, info
#
# File ~/Documents/Graduate_School/24_Fall/CS138/Fa24-CS-138-_FinalProject/.venv/lib/python3.10/site-packages/gymnasium/core.py:502, in RewardWrapper.step(self, action)
#     498 def step(
#     499     self, action: ActType
#     500 ) -> tuple[ObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     501     """Modifies the :attr:`env` :meth:`step` reward using :meth:`self.reward`."""
# --> 502     observation, reward, terminated, truncated, info = self.env.step(action)
#     503     return observation, self.reward(reward), terminated, truncated, info
#
# File ~/Documents/Graduate_School/24_Fall/CS138/Fa24-CS-138-_FinalProject/.venv/lib/python3.10/site-packages/gymnasium/core.py:538, in ActionWrapper.step(self, action)
#     534 def step(
#     535     self, action: WrapperActType
#     536 ) -> tuple[ObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     537     """Runs the :attr:`env` :meth:`env.step` using the modified ``action`` from :meth:`self.action`."""
# --> 538     return self.env.step(self.action(action))
#
# File ~/Documents/Graduate_School/24_Fall/CS138/Fa24-CS-138-_FinalProject/.venv/lib/python3.10/site-packages/gymnasium/core.py:470, in ObservationWrapper.step(self, action)
#     468 """Modifies the :attr:`env` after calling :meth:`step` using :meth:`self.observation` on the returned observations."""
#     469 observation, reward, terminated, truncated, info = self.env.step(action)
# --> 470 return self.observation(observation), reward, terminated, truncated, info
#
# File ~/Documents/Graduate_School/24_Fall/CS138/Fa24-CS-138-_FinalProject/.venv/lib/python3.10/site-packages/citylearn/wrappers.py:33, in ClippedObservationWrapper.observation(self, observations)
#      30 def observation(self, observations: List[List[float]]) -> List[List[float]]:
#      31     """Returns normalized observations."""
# ---> 33     for i, (o, s) in enumerate(zip(observations, self.observation_space)):
#      34         for j, (o_, l, u) in enumerate(zip(o, s.low, s.high)):
#      35             observations[i][j] = min(max(o_, l), u)
#
# File ~/Documents/Graduate_School/24_Fall/CS138/Fa24-CS-138-_FinalProject/.venv/lib/python3.10/site-packages/gymnasium/core.py:351, in Wrapper.observation_space(self)
#     349 """Return the :attr:`Env` :attr:`observation_space` unless overwritten then the wrapper :attr:`observation_space` is used."""
#     350 if self._observation_space is None:
# --> 351     return self.env.observation_space
#     352 return self._observation_space
#
# File ~/Documents/Graduate_School/24_Fall/CS138/Fa24-CS-138-_FinalProject/.venv/lib/python3.10/site-packages/citylearn/wrappers.py:118, in NormalizedObservationWrapper.observation_space(self)
#     116 for i, b in enumerate(self.env.unwrapped.buildings):
#     117     s = b.estimate_observation_space(normalize=True)
# --> 118     o = b.observations(normalize=True, periodic_normalization=True)
#     120     for k, lv, hv in zip(o, s.low, s.high):
#     121         if i == 0 or k not in self.shared_observations or k not in shared_observations:
#
# File ~/Documents/Graduate_School/24_Fall/CS138/Fa24-CS-138-_FinalProject/.venv/lib/python3.10/site-packages/citylearn/building.py:870, in Building.observations(self, include_all, normalize, periodic_normalization, check_limits)
#     867 check_limits = False if check_limits is None else check_limits
#     869 observations = {}
# --> 870 data = self._get_observations_data()
#     872 if include_all:
#     873     valid_observations = list(data.keys())
#
# File ~/Documents/Graduate_School/24_Fall/CS138/Fa24-CS-138-_FinalProject/.venv/lib/python3.10/site-packages/citylearn/building.py:975, in Building._get_observations_data(self)
#     973 def _get_observations_data(self) -> Mapping[str, Union[float, int]]:
#     974     return {
# --> 975         **{
#     976             k.lstrip('_'): self.energy_simulation.__getattr__(k.lstrip('_'))[self.time_step]
#     977             for k, v in vars(self.energy_simulation).items() if isinstance(v, np.ndarray)
#     978         },
#     979         **{
#     980             k.lstrip('_'): self.weather.__getattr__(k.lstrip('_'))[self.time_step]
#     981             for k, v in vars(self.weather).items() if isinstance(v, np.ndarray)
#     982         },
#     983         **{
#     984             k.lstrip('_'): self.pricing.__getattr__(k.lstrip('_'))[self.time_step]
#     985             for k, v in vars(self.pricing).items() if isinstance(v, np.ndarray)
#     986         },
#     987         **{
#     988             k.lstrip('_'): self.carbon_intensity.__getattr__(k.lstrip('_'))[self.time_step]
#     989             for k, v in vars(self.carbon_intensity).items() if isinstance(v, np.ndarray)
#     990         },
#     991         'solar_generation':abs(self.solar_generation[self.time_step]),
#     992         **{
#     993             'cooling_storage_soc':self.cooling_storage.soc[self.time_step],
#     994             'heating_storage_soc':self.heating_storage.soc[self.time_step],
#     995             'dhw_storage_soc':self.dhw_storage.soc[self.time_step],
#     996             'electrical_storage_soc':self.electrical_storage.soc[self.time_step],
#     997         },
#     998         'cooling_demand': self.__energy_from_cooling_device[self.time_step] + abs(min(self.cooling_storage.energy_balance[self.time_step], 0.0)),
#     999         'heating_demand': self.__energy_from_heating_device[self.time_step] + abs(min(self.heating_storage.energy_balance[self.time_step], 0.0)),
#    1000         'dhw_demand': self.__energy_from_dhw_device[self.time_step] + abs(min(self.dhw_storage.energy_balance[self.time_step], 0.0)),
#    1001         'net_electricity_consumption': self.net_electricity_consumption[self.time_step],
#    1002         'cooling_electricity_consumption': self.cooling_electricity_consumption[self.time_step],
#    1003         'heating_electricity_consumption': self.heating_electricity_consumption[self.time_step],
#    1004         'dhw_electricity_consumption': self.dhw_electricity_consumption[self.time_step],
#    1005         'cooling_storage_electricity_consumption': self.cooling_storage_electricity_consumption[self.time_step],
#    1006         'heating_storage_electricity_consumption': self.heating_storage_electricity_consumption[self.time_step],
#    1007         'dhw_storage_electricity_consumption': self.dhw_storage_electricity_consumption[self.time_step],
#    1008         'electrical_storage_electricity_consumption': self.electrical_storage_electricity_consumption[self.time_step],
#    1009         'cooling_device_efficiency': self.cooling_device.get_cop(self.weather.outdoor_dry_bulb_temperature[self.time_step], heating=False),
#    1010         'heating_device_efficiency': self.heating_device.get_cop(
#    1011             self.weather.outdoor_dry_bulb_temperature[self.time_step], heating=True
#    1012                 ) if isinstance(self.heating_device, HeatPump) else self.heating_device.efficiency,
#    1013         'dhw_device_efficiency': self.dhw_device.get_cop(
#    1014             self.weather.outdoor_dry_bulb_temperature[self.time_step], heating=True
#    1015                 ) if isinstance(self.dhw_device, HeatPump) else self.dhw_device.efficiency,
#    1016         'indoor_dry_bulb_temperature_cooling_set_point': self.energy_simulation.indoor_dry_bulb_temperature_cooling_set_point[self.time_step],
#    1017         'indoor_dry_bulb_temperature_heating_set_point': self.energy_simulation.indoor_dry_bulb_temperature_heating_set_point[self.time_step],
#    1018         'indoor_dry_bulb_temperature_cooling_delta': self.energy_simulation.indoor_dry_bulb_temperature[self.time_step] - self.energy_simulation.indoor_dry_bulb_temperature_cooling_set_point[self.time_step],
#    1019         'indoor_dry_bulb_temperature_heating_delta': self.energy_simulation.indoor_dry_bulb_temperature[self.time_step] - self.energy_simulation.indoor_dry_bulb_temperature_heating_set_point[self.time_step],
#    1020         'comfort_band': self.energy_simulation.comfort_band[self.time_step],
#    1021         'occupant_count': self.energy_simulation.occupant_count[self.time_step],
#    1022         'power_outage': self.__power_outage_signal[self.time_step],
#    1023     }
#
# File ~/Documents/Graduate_School/24_Fall/CS138/Fa24-CS-138-_FinalProject/.venv/lib/python3.10/site-packages/citylearn/building.py:976, in <dictcomp>(.0)
#     973 def _get_observations_data(self) -> Mapping[str, Union[float, int]]:
#     974     return {
#     975         **{
# --> 976             k.lstrip('_'): self.energy_simulation.__getattr__(k.lstrip('_'))[self.time_step]
#     977             for k, v in vars(self.energy_simulation).items() if isinstance(v, np.ndarray)
#     978         },
#     979         **{
#     980             k.lstrip('_'): self.weather.__getattr__(k.lstrip('_'))[self.time_step]
#     981             for k, v in vars(self.weather).items() if isinstance(v, np.ndarray)
#     982         },
#     983         **{
#     984             k.lstrip('_'): self.pricing.__getattr__(k.lstrip('_'))[self.time_step]
#     985             for k, v in vars(self.pricing).items() if isinstance(v, np.ndarray)
#     986         },
#     987         **{
#     988             k.lstrip('_'): self.carbon_intensity.__getattr__(k.lstrip('_'))[self.time_step]
#     989             for k, v in vars(self.carbon_intensity).items() if isinstance(v, np.ndarray)
#     990         },
#     991         'solar_generation':abs(self.solar_generation[self.time_step]),
#     992         **{
#     993             'cooling_storage_soc':self.cooling_storage.soc[self.time_step],
#     994             'heating_storage_soc':self.heating_storage.soc[self.time_step],
#     995             'dhw_storage_soc':self.dhw_storage.soc[self.time_step],
#     996             'electrical_storage_soc':self.electrical_storage.soc[self.time_step],
#     997         },
#     998         'cooling_demand': self.__energy_from_cooling_device[self.time_step] + abs(min(self.cooling_storage.energy_balance[self.time_step], 0.0)),
#     999         'heating_demand': self.__energy_from_heating_device[self.time_step] + abs(min(self.heating_storage.energy_balance[self.time_step], 0.0)),
#    1000         'dhw_demand': self.__energy_from_dhw_device[self.time_step] + abs(min(self.dhw_storage.energy_balance[self.time_step], 0.0)),
#    1001         'net_electricity_consumption': self.net_electricity_consumption[self.time_step],
#    1002         'cooling_electricity_consumption': self.cooling_electricity_consumption[self.time_step],
#    1003         'heating_electricity_consumption': self.heating_electricity_consumption[self.time_step],
#    1004         'dhw_electricity_consumption': self.dhw_electricity_consumption[self.time_step],
#    1005         'cooling_storage_electricity_consumption': self.cooling_storage_electricity_consumption[self.time_step],
#    1006         'heating_storage_electricity_consumption': self.heating_storage_electricity_consumption[self.time_step],
#    1007         'dhw_storage_electricity_consumption': self.dhw_storage_electricity_consumption[self.time_step],
#    1008         'electrical_storage_electricity_consumption': self.electrical_storage_electricity_consumption[self.time_step],
#    1009         'cooling_device_efficiency': self.cooling_device.get_cop(self.weather.outdoor_dry_bulb_temperature[self.time_step], heating=False),
#    1010         'heating_device_efficiency': self.heating_device.get_cop(
#    1011             self.weather.outdoor_dry_bulb_temperature[self.time_step], heating=True
#    1012                 ) if isinstance(self.heating_device, HeatPump) else self.heating_device.efficiency,
#    1013         'dhw_device_efficiency': self.dhw_device.get_cop(
#    1014             self.weather.outdoor_dry_bulb_temperature[self.time_step], heating=True
#    1015                 ) if isinstance(self.dhw_device, HeatPump) else self.dhw_device.efficiency,
#    1016         'indoor_dry_bulb_temperature_cooling_set_point': self.energy_simulation.indoor_dry_bulb_temperature_cooling_set_point[self.time_step],
#    1017         'indoor_dry_bulb_temperature_heating_set_point': self.energy_simulation.indoor_dry_bulb_temperature_heating_set_point[self.time_step],
#    1018         'indoor_dry_bulb_temperature_cooling_delta': self.energy_simulation.indoor_dry_bulb_temperature[self.time_step] - self.energy_simulation.indoor_dry_bulb_temperature_cooling_set_point[self.time_step],
#    1019         'indoor_dry_bulb_temperature_heating_delta': self.energy_simulation.indoor_dry_bulb_temperature[self.time_step] - self.energy_simulation.indoor_dry_bulb_temperature_heating_set_point[self.time_step],
#    1020         'comfort_band': self.energy_simulation.comfort_band[self.time_step],
#    1021         'occupant_count': self.energy_simulation.occupant_count[self.time_step],
#    1022         'power_outage': self.__power_outage_signal[self.time_step],
#    1023     }
#
# File ~/Documents/Graduate_School/24_Fall/CS138/Fa24-CS-138-_FinalProject/.venv/lib/python3.10/site-packages/citylearn/base.py:182, in Environment.time_step(self)
#     177     """:py:class:`citylearn.base.EpisodeTracker` object used to keep track of
#     178     current episode time steps for reading observations from data files."""
#     180     return self.__episode_tracker
# --> 182 @property
#     183 def time_step(self) -> int:
#     184     r"""Current environment time step."""
#     186     return self.__time_step
#
# KeyboardInterrupt:

# %% [markdown]
# #### Multi-agent
#
# The multi-agent interface for RLlib is the `RLlibMultiAgentEnv` wrapper.

# %%
import warnings
from citylearn.wrappers import ClippedObservationWrapper, NormalizedObservationWrapper, RLlibMultiAgentEnv
from ray.rllib.algorithms.sac import SACConfig as Config
from ray.rllib.policy.policy import PolicySpec

warnings.filterwarnings('ignore', category=DeprecationWarning)

# initialize
env_config = {
    'env_kwargs': {
        'schema': 'citylearn_challenge_2023_phase_2_local_evaluation',
    },
    'wrappers': [
        NormalizedObservationWrapper, 
        ClippedObservationWrapper
    ]
}
config = (
    Config()
    .environment(RLlibMultiAgentEnv, env_config=env_config)
    .multi_agent(
        policies={a: PolicySpec() for a in RLlibMultiAgentEnv(env_config)._agent_ids},
        policy_mapping_fn=lambda agent_id, episode, worker, **kwargs: agent_id,
    )
)
model = config.build()

# train
for i in range(2):
    _ = model.train()

# test
env = RLlibMultiAgentEnv(env_config)
observations, _ = env.reset()

while not env.terminated:
    actions = {p: model.compute_single_action(o, policy_id=p, explore=False) for p, o in observations.items()}
    observations, _, _, _, _ = env.step(actions)

kpis = env.unwrapped.evaluate()
kpis = kpis.pivot(index='cost_function', columns='name', values='value').round(3)
kpis = kpis.dropna(how='all')
display(kpis)
# Out:
# /home/casey/Documents/Graduate_School/24_Fall/CS138/Fa24-CS-138-_FinalProject/.venv/lib/python3.10/site-packages/citylearn/dynamics.py:118: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.load_state_dict(torch.load(self.filepath)['model_state_dict'])
# /home/casey/Documents/Graduate_School/24_Fall/CS138/Fa24-CS-138-_FinalProject/.venv/lib/python3.10/site-packages/citylearn/dynamics.py:118: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.load_state_dict(torch.load(self.filepath)['model_state_dict'])
# 2024-11-25 15:48:59,462	WARNING util.py:62 -- Install gputil for GPU system monitoring.
# /home/casey/Documents/Graduate_School/24_Fall/CS138/Fa24-CS-138-_FinalProject/.venv/lib/python3.10/site-packages/citylearn/dynamics.py:118: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.load_state_dict(torch.load(self.filepath)['model_state_dict'])
# name                                           Building_1  Building_2  \
# cost_function
# all_time_peak_average                                 NaN         NaN
# annual_normalized_unserved_energy_total             0.015       0.016
# carbon_emissions_total                              1.639       1.595
# cost_total                                          1.579       1.544
# daily_one_minus_load_factor_average                   NaN         NaN
# daily_peak_average                                    NaN         NaN
# discomfort_cold_delta_average                       7.907       2.924
# discomfort_cold_delta_maximum                      12.499       8.406
# discomfort_cold_delta_minimum                       0.000       0.000
# discomfort_cold_proportion                          0.969       0.743
# discomfort_hot_delta_average                        0.011       0.087
# discomfort_hot_delta_maximum                        2.255       5.451
# discomfort_hot_delta_minimum                        0.000       0.000
# discomfort_hot_proportion                           0.001       0.017
# discomfort_proportion                               0.971       0.759
# electricity_consumption_total                       1.650       1.622
# monthly_one_minus_load_factor_average                 NaN         NaN
# one_minus_thermal_resilience_proportion             0.733       0.643
# power_outage_normalized_unserved_energy_total       0.783       0.796
# ramping_average                                       NaN         NaN
# zero_net_energy                                     1.695       1.638
#
# name                                           Building_3  District
# cost_function
# all_time_peak_average                                 NaN     1.063
# annual_normalized_unserved_energy_total             0.014     0.015
# carbon_emissions_total                              1.459     1.564
# cost_total                                          1.428     1.517
# daily_one_minus_load_factor_average                   NaN     0.740
# daily_peak_average                                    NaN     1.167
# discomfort_cold_delta_average                       2.584     4.471
# discomfort_cold_delta_maximum                       5.322     8.742
# discomfort_cold_delta_minimum                       0.000     0.000
# discomfort_cold_proportion                          0.764     0.825
# discomfort_hot_delta_average                        0.013     0.037
# discomfort_hot_delta_maximum                        3.476     3.728
# discomfort_hot_delta_minimum                        0.000     0.000
# discomfort_hot_proportion                           0.003     0.007
# discomfort_proportion                               0.767     0.832
# electricity_consumption_total                       1.479     1.584
# monthly_one_minus_load_factor_average                 NaN     0.890
# one_minus_thermal_resilience_proportion             0.267     0.548
# power_outage_normalized_unserved_energy_total       0.707     0.762
# ramping_average                                       NaN     0.884
# zero_net_energy                                     1.488     1.607

# %% [markdown]
# ## Neighborhood Dataset Generation
#
# Aside the provided datasets that come with the CityLearn installation, custom single-family residential datasets can be generated in CityLearn by taking advantage of the [End-Use Load Profiles for the U.S. Building Stock dataset](https://www.nrel.gov/buildings/end-use-load-profiles.html). The [citylearn.end_use_load_profiles.neighborhood.Neighborhood](https://www.citylearn.net/api/citylearn.end_use_load_profiles.neighborhood.html#citylearn.end_use_load_profiles.neighborhood.Neighborhood) class makes this possible.
#
# To learn more about the methodology used in this feature, refer to the [CityLearn v2 paper](https://doi.org/10.1080/19401493.2024.2418813).
#
# Note that to make use of this feature, [EnergyPlus 9.6.0](https://github.com/NREL/EnergyPlus/releases/tag/v9.6.0) must be installed. Other EnergyPlus versions are not yet supported.
#
# An example of a generating a dataset and using it in simulation is:

# %%
from citylearn.agents.rbc import BasicRBC as Agent
from citylearn.citylearn import CityLearnEnv
from citylearn.end_use_load_profiles.neighborhood import Neighborhood, SampleMethod

# path to version EnergyPlus 9.6.0 IDD
idd_filepath = '/Applications/EnergyPlus-9-6-0/PreProcess/IDFVersionUpdater/V9-6-0-Energy+.idd'

# build a neighborhood with n buildings through random sampling of single-family residential buildings in EULP dataset.
# Sampling population is filtered to include specific county and building vintage.
# train their LSTM thermal dynamics models and generate a CityLearn schema for the two buildings
neighborhood = Neighborhood()
n = 2
neighborhood_build = neighborhood.build(
    idd_filepath=idd_filepath,
    delete_energyplus_simulation_output=True,
    sample_buildings_kwargs=dict(
        sample_method=SampleMethod.RANDOM,
        sample_count=n,
        filters={
            'in.resstock_county_id': ['TX, Travis County'],
            'in.vintage': ['2000s']
        },
    ),
)

# simulate neighborhood in CityLearn
env = CityLearnEnv(neighborhood_build.schema_filepath, central_agent=True)
model = Agent(env)
observations, _ = env.reset()

while not env.terminated:
    actions = model.predict(observations)
    observations, reward, info, terminated, truncated = env.step(actions)

kpis = model.env.evaluate()
kpis = kpis.pivot(index='cost_function', columns='name', values='value').round(3)
kpis = kpis.dropna(how='all')
display(kpis)
# Out:
# [openstudio.energyplus.ForwardTranslator] <0> Cannot find file ""
# [openstudio.energyplus.ForwardTranslator] <0> Cannot find file ""
# [openstudio.energyplus.ForwardTranslator] <0> Cannot find file ""
# [openstudio.energyplus.ForwardTranslator] <0> Cannot find file ""
# [openstudio.energyplus.ForwardTranslator] <0> Cannot find file ""
# [openstudio.energyplus.ForwardTranslator] <0> Cannot find file ""
# [openstudio.energyplus.ForwardTranslator] <0> Cannot find file ""
# [openstudio.energyplus.ForwardTranslator] <0> Cannot find file ""
# [openstudio.energyplus.ForwardTranslator] <0> Cannot find file ""
# [openstudio.energyplus.ForwardTranslator] <0> Cannot find file ""
# [openstudio.energyplus.ForwardTranslator] <0> Cannot find file ""
# [openstudio.energyplus.ForwardTranslator] <0> Cannot find file ""
# [openstudio.energyplus.ForwardTranslator] <0> Cannot find file ""
# [openstudio.energyplus.ForwardTranslator] <0> Cannot find file ""
# [utilities.idf.WorkspaceObject] <0> Object of type 'Schedule:Constant' and named 'Always On Continuous', points to an object named Fractional 1 from field 1, but that object cannot be located.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 13
#      11 neighborhood = Neighborhood()
#      12 n = 2
# ---> 13 neighborhood_build = neighborhood.build(
#      14     idd_filepath=idd_filepath,
#      15     delete_energyplus_simulation_output=True,
#      16     sample_buildings_kwargs=dict(
#      17         sample_method=SampleMethod.RANDOM,
#      18         sample_count=n,
#      19         filters={
#      20             'in.resstock_county_id': ['TX, Travis County'],
#      21             'in.vintage': ['2000s']
#      22         },
#      23     ),
#      24 )
#      26 # simulate neighborhood in CityLearn
#      27 env = CityLearnEnv(neighborhood_build.schema_filepath, central_agent=True)
#
# File ~/Documents/Graduate_School/24_Fall/CS138/Fa24-CS-138-_FinalProject/.venv/lib/python3.10/site-packages/citylearn/end_use_load_profiles/neighborhood.py:184, in Neighborhood.build(self, idd_filepath, bldg_ids, include_lstm_models, test_lstm_models, test_citylearn_simulation, delete_energyplus_simulation_output, sample_buildings_kwargs, energyplus_simulation_kwargs, train_lstm_kwargs, schema_kwargs, test_citylearn_simulation_kwargs)
#     181     pass
#     183 # run energyplus simulations
# --> 184 simulators = self.simulate_energy_plus(bldg_ids, idd_filepath, **energyplus_simulation_kwargs)
#     186 # train LSTM models
#     187 if include_lstm_models:
#
# File ~/Documents/Graduate_School/24_Fall/CS138/Fa24-CS-138-_FinalProject/.venv/lib/python3.10/site-packages/citylearn/end_use_load_profiles/neighborhood.py:627, in Neighborhood.simulate_energy_plus(self, bldg_ids, idd_filepath, simulation_ids, models, schedules, osm, partial_loads_simulations, partial_loads_kwargs, **kwargs)
#     625 _simulation_id = f'{simulation_id}-mechanical'
#     626 _output_directory = os.path.join(output_directory, _simulation_id)
# --> 627 mechanical_simulator = self.end_use_load_profiles.simulate_building(
#     628     ideal_loads=False,
#     629     simulation_id=_simulation_id,
#     630     output_directory=_output_directory,
#     631     **_kwargs
#     632 ).simulator
#     634 # ideal loads
#     635 _simulation_id = f'{simulation_id}-ideal'
#
# File ~/Documents/Graduate_School/24_Fall/CS138/Fa24-CS-138-_FinalProject/.venv/lib/python3.10/site-packages/doe_xstock/end_use_load_profiles.py:144, in EndUseLoadProfiles.simulate_building(self, bldg_id, idd_filepath, ideal_loads, edit_ems, simulation_id, output_directory, output_variables, output_meters, default_output_variables, default_output_meters, model, epw, osm, schedules, number_of_time_steps_per_hour, **kwargs)
#     121 def simulate_building(
#     122     self, bldg_id: int, idd_filepath: Union[str, Path], ideal_loads: bool = None, edit_ems: bool = None, simulation_id: str = None,
#     123     output_directory: Union[Path, str] = None, output_variables: List[str] = None, output_meters: List[str] = None,
#     124     default_output_variables: bool = None, default_output_meters: bool = None, model: Union[Path, str] = None, epw: Union[Path, str] = None,
#     125     osm: bool = None, schedules: Union[Path, DataFrame, str] = None, number_of_time_steps_per_hour: int = None, **kwargs
#     126 ) -> EndUseLoadProfilesBuilding:
#     127     building = self.prepare_building_for_simulation(
#     128         bldg_id,
#     129         idd_filepath,
#    (...)
#     142         number_of_time_steps_per_hour=number_of_time_steps_per_hour,
#     143     )
# --> 144     building.simulator.simulate(**kwargs)
#     146     return building
#
# File ~/Documents/Graduate_School/24_Fall/CS138/Fa24-CS-138-_FinalProject/.venv/lib/python3.10/site-packages/doe_xstock/simulate.py:372, in EndUseLoadProfilesEnergyPlusSimulator.simulate(self, **run_kwargs)
#     370 while True:
#     371     try:
# --> 372         super().simulate(**run_kwargs)
#     373         break
#     375     except EnergyPlusRunError as e:
#
# File ~/Documents/Graduate_School/24_Fall/CS138/Fa24-CS-138-_FinalProject/.venv/lib/python3.10/site-packages/doe_xstock/simulate.py:234, in EnergyPlusSimulator.simulate(self, **run_kwargs)
#     232 def simulate(self, **run_kwargs):
#     233     os.makedirs(self.output_directory, exist_ok=True)
# --> 234     run_kwargs = self.get_run_kwargs(**run_kwargs if run_kwargs is not None else {})
#     235     self.__write_epw()
#     236     idf = self.preprocess_idf_for_simulation()
#
# File ~/Documents/Graduate_School/24_Fall/CS138/Fa24-CS-138-_FinalProject/.venv/lib/python3.10/site-packages/doe_xstock/simulate.py:249, in EnergyPlusSimulator.get_run_kwargs(self, **kwargs)
#     248 def get_run_kwargs(self, **kwargs) -> Mapping[str, Union[bool, str]]:
# --> 249     idf = self.get_idf_object()
#     250     idf_version = idf.idfobjects['version'][0].Version_Identifier.split('.')
#     251     idf_version.extend([0] * (3 - len(idf_version)))
#
# File ~/Documents/Graduate_School/24_Fall/CS138/Fa24-CS-138-_FinalProject/.venv/lib/python3.10/site-packages/doe_xstock/simulate.py:299, in EnergyPlusSimulator.get_idf_object(self, epw_filepath)
#     296 idf = StringIO(self.idf)
#     298 try:
# --> 299     idf = IDF(idf, epw_filepath)
#     301 except IDDNotSetError as e:
#     302     self.idd_filepath = self.idd_filepath
#
# File ~/Documents/Graduate_School/24_Fall/CS138/Fa24-CS-138-_FinalProject/.venv/lib/python3.10/site-packages/eppy/modeleditor.py:579, in IDF.__init__(self, idfname, epw)
#     577         self.idfabsname = None
#     578         pass  # it is file handle. the code can handle that
# --> 579     self.read()
#     581 if epw != None:
#     582     self.epw = epw
#
# File ~/Documents/Graduate_School/24_Fall/CS138/Fa24-CS-138-_FinalProject/.venv/lib/python3.10/site-packages/eppy/modeleditor.py:712, in IDF.read(self)
#     707     errortxt = (
#     708         "IDD file needed to read the idf file. "
#     709         "Set it using IDF.setiddname(iddfile)"
#     710     )
#     711     raise IDDNotSetError(errortxt)
# --> 712 readout = idfreader1(
#     713     self.idfname, self.iddname, self, commdct=self.idd_info, block=self.block
#     714 )
#     715 (self.idfobjects, block, self.model, idd_info, idd_index, idd_version) = readout
#     716 self.__class__.setidd(idd_info, idd_index, block, idd_version)
#
# File ~/Documents/Graduate_School/24_Fall/CS138/Fa24-CS-138-_FinalProject/.venv/lib/python3.10/site-packages/eppy/idfreader.py:268, in idfreader1(fname, iddfile, theidf, conv, commdct, block)
#     266 def idfreader1(fname, iddfile, theidf, conv=True, commdct=None, block=None):
#     267     """read idf file and return bunches"""
# --> 268     versiontuple = iddversiontuple(iddfile)
#     269     # import pdb; pdb.set_trace()
#     270     block, data, commdct, idd_index = readidf.readdatacommdct1(
#     271         fname, iddfile=iddfile, commdct=commdct, block=block
#     272     )
#
# File ~/Documents/Graduate_School/24_Fall/CS138/Fa24-CS-138-_FinalProject/.venv/lib/python3.10/site-packages/eppy/idfreader.py:41, in iddversiontuple(afile)
#      38     return tuple([int(num) for num in vers.split(".")])
#      40 try:
# ---> 41     fhandle = open(afile, "rb")
#      42 except TypeError:
#      43     fhandle = afile
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Applications/EnergyPlus-9-6-0/PreProcess/IDFVersionUpdater/V9-6-0-Energy+.idd'
